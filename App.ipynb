# %%
import pandas as pd

# %%
dataFrame=pd.read_excel("dataset.xlsx")
dataFrame.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dataFrame=pd.read_excel("dataset.xlsx")
#       2 dataFrame.shape()
#
# NameError: name 'pd' is not defined

# %%
dataFrame.head()
# Out:
#    F1        F2         F3              F4              F5     F6  F7  F8  F9  \
# 0   1  10797460  K00752.01       CONFIRMED       CANDIDATE  1.000   0   0   0
# 1   2  10797460  K00752.02       CONFIRMED       CANDIDATE  0.969   0   0   0
# 2   3  10811496  K00753.01  FALSE POSITIVE  FALSE POSITIVE  0.000   0   1   0
# 3   4  10848459  K00754.01  FALSE POSITIVE  FALSE POSITIVE  0.000   0   1   0
# 4   5  10854555  K00755.01       CONFIRMED       CANDIDATE  1.000   0   0   0
#
#    F10  ...    F41    F42    F43    F44    F45    F46    F47        F48  \
# 0    0  ...  -81.0  4.467  0.064 -0.096  0.927  0.105 -0.061  291.93423
# 1    0  ...  -81.0  4.467  0.064 -0.096  0.927  0.105 -0.061  291.93423
# 2    0  ... -176.0  4.544  0.044 -0.176  0.868  0.233 -0.078  297.00482
# 3    0  ... -174.0  4.564  0.053 -0.168  0.791  0.201 -0.067  285.53461
# 4    0  ... -211.0  4.438  0.070 -0.210  1.046  0.334 -0.133  288.75488
#
#          F49  Target
# 0  48.141651  15.347
# ...

# %%
import matplotlib as plt
